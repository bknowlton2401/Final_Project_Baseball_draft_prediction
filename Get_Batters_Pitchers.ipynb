# %%
import pandas as pd

# %%
file = 'Resources/first_round_csvs/AllFirstRoundDrafts.csv'
all_players = pd.read_csv(file)
all_players
# Out:
#      Year Rnd  DT  OvPck  FrRnd  RdPck            Tm Signed        Bonus  \
# 0    2011   1 NaN      1  FrRnd      1       Pirates      Y  $8,000,000
# 1    2011   1 NaN      2  FrRnd      2      Mariners      Y  $6,350,000
# 2    2011   1 NaN      3  FrRnd      3  Diamondbacks      Y  $3,400,000
# 3    2011   1 NaN      4  FrRnd      4       Orioles      Y  $4,000,000
# 4    2011   1 NaN      5  FrRnd      5        Royals      Y  $7,500,000
# ..    ...  ..  ..    ...    ...    ...           ...    ...          ...
# 741  2005  1s NaN     44  FrRnd     44       Marlins      Y    $775,000
# 742  2005  1s NaN     45  FrRnd     45       Red Sox      Y    $762,000
# 743  2005  1s NaN     46  FrRnd     46     Cardinals      Y    $675,000
# 744  2005  1s NaN     47  FrRnd     47       Red Sox      Y    $730,000
# 745  2005  1s NaN     48  FrRnd     48       Orioles      Y    $650,000
#
#                         Name  ...     BA    OPS    G.1      W     L   ERA  \
# 0        Gerrit Cole(minors)  ...  0.163  0.393  250.0  124.0  65.0  3.19
# 1      Danny Hultzen(minors)  ...    NaN    NaN    6.0    0.0   0.0  0.00
# 2       Trevor Bauer(minors)  ...  0.069  0.185  222.0   83.0  69.0  3.79
# 3        Dylan Bundy(minors)  ...  0.143  0.286  175.0   50.0  61.0  4.70
# 4     Bubba Starling(minors)  ...  0.204  0.544    NaN    NaN   NaN   NaN
# ..                       ...  ...    ...    ...    ...    ...   ...   ...
# 741       *Sean West(minors)  ...  0.059  0.147   22.0    8.0   8.0  5.03
# 742      *Jed Lowrie(minors)  ...  0.257  0.737    NaN    NaN   NaN   NaN
# 743    *Tyler Herron(minors)  ...    NaN    NaN    NaN    NaN   NaN   NaN
# 744  *Michael Bowden(minors)  ...  0.000  0.000  103.0    3.0   5.0  4.51
# 745   *Garrett Olson(minors)  ...  0.167  0.310  104.0   14.0  22.0  6.26
#
#      WHIP   SV  Type                                     Drafted Out of
# 0    1.11  0.0   4Yr  University of California, Los Angeles (Los Ang...
# 1    1.80  0.0   4Yr       University of Virginia (Charlottesville, VA)
# 2    1.24  1.0   4Yr  University of California, Los Angeles (Los Ang...
# 3    1.30  0.0    HS                             Owasso HS (Owasso, OK)
# 4     NaN  NaN    HS                  Gardner-Edgerton HS (Gardner, KS)
# ..    ...  ...   ...                                                ...
# 741  1.58  0.0    HS                 Captain Shreve HS (Shreveport, LA)
# 742   NaN  NaN   4Yr                Stanford University (Palo Alto, CA)
# 743   NaN  NaN    HS           Wellington Community HS (Wellington, FL)
# 744  1.40  0.0    HS                   Waubonsie Valley HS (Aurora, IL)
# 745  1.67  1.0   4Yr  California Polytechnic State University, San L...
#
# [746 rows x 25 columns]

# %%
all_players.columns
# Out:
# Index(['Year', 'Rnd', 'DT', 'OvPck', 'FrRnd', 'RdPck', 'Tm', 'Signed', 'Bonus',
#        'Name', 'Pos', 'WAR', 'G', 'AB', 'HR', 'BA', 'OPS', 'G.1', 'W', 'L',
#        'ERA', 'WHIP', 'SV', 'Type', 'Drafted Out of'],
#       dtype='object')

# %%
print(all_players['Pos'])
# Out:
# 0      RHP
# 1      LHP
# 2      RHP
# 3      RHP
# 4       OF
#       ...
# 741    LHP
# 742     2B
# 743    RHP
# 744    RHP
# 745    LHP
# Name: Pos, Length: 746, dtype: object

# %%
all_players.groupby(["Pos"]).count()['Year']
# Out:
# Pos
# 1B      26
# 2B      17
# 3B      54
# C       48
# CF      21
# LF       2
# LHP    113
# OF     100
# RF       5
# RHP    271
# SS      87
# lHP      2
# Name: Year, dtype: int64

# %%
new_col_order = ['Name','Year', 'OvPck', 'RdPck', 'Rnd','Tm', 'Pos', 'DT', 'FrRnd','Signed', 'Bonus',
                 'WAR', 'G', 'AB', 'HR', 'BA', 'OPS', 'G.1', 'W', 'L',
       'ERA', 'WHIP', 'SV', 'Type', 'Drafted Out of']

# %%
all_players = all_players[new_col_order]
all_players
# Out:
#                         Name  Year  OvPck  RdPck Rnd            Tm  Pos  DT  \
# 0        Gerrit Cole(minors)  2011      1      1   1       Pirates  RHP NaN
# 1      Danny Hultzen(minors)  2011      2      2   1      Mariners  LHP NaN
# 2       Trevor Bauer(minors)  2011      3      3   1  Diamondbacks  RHP NaN
# 3        Dylan Bundy(minors)  2011      4      4   1       Orioles  RHP NaN
# 4     Bubba Starling(minors)  2011      5      5   1        Royals   OF NaN
# ..                       ...   ...    ...    ...  ..           ...  ...  ..
# 741       *Sean West(minors)  2005     44     44  1s       Marlins  LHP NaN
# 742      *Jed Lowrie(minors)  2005     45     45  1s       Red Sox   2B NaN
# 743    *Tyler Herron(minors)  2005     46     46  1s     Cardinals  RHP NaN
# 744  *Michael Bowden(minors)  2005     47     47  1s       Red Sox  RHP NaN
# 745   *Garrett Olson(minors)  2005     48     48  1s       Orioles  LHP NaN
#
#      FrRnd Signed  ...     BA    OPS    G.1      W     L   ERA  WHIP   SV  \
# 0    FrRnd      Y  ...  0.163  0.393  250.0  124.0  65.0  3.19  1.11  0.0
# 1    FrRnd      Y  ...    NaN    NaN    6.0    0.0   0.0  0.00  1.80  0.0
# 2    FrRnd      Y  ...  0.069  0.185  222.0   83.0  69.0  3.79  1.24  1.0
# 3    FrRnd      Y  ...  0.143  0.286  175.0   50.0  61.0  4.70  1.30  0.0
# 4    FrRnd      Y  ...  0.204  0.544    NaN    NaN   NaN   NaN   NaN  NaN
# ..     ...    ...  ...    ...    ...    ...    ...   ...   ...   ...  ...
# 741  FrRnd      Y  ...  0.059  0.147   22.0    8.0   8.0  5.03  1.58  0.0
# 742  FrRnd      Y  ...  0.257  0.737    NaN    NaN   NaN   NaN   NaN  NaN
# 743  FrRnd      Y  ...    NaN    NaN    NaN    NaN   NaN   NaN   NaN  NaN
# 744  FrRnd      Y  ...  0.000  0.000  103.0    3.0   5.0  4.51  1.40  0.0
# 745  FrRnd      Y  ...  0.167  0.310  104.0   14.0  22.0  6.26  1.67  1.0
#
#      Type                                     Drafted Out of
# 0     4Yr  University of California, Los Angeles (Los Ang...
# 1     4Yr       University of Virginia (Charlottesville, VA)
# 2     4Yr  University of California, Los Angeles (Los Ang...
# 3      HS                             Owasso HS (Owasso, OK)
# 4      HS                  Gardner-Edgerton HS (Gardner, KS)
# ..    ...                                                ...
# 741    HS                 Captain Shreve HS (Shreveport, LA)
# 742   4Yr                Stanford University (Palo Alto, CA)
# 743    HS           Wellington Community HS (Wellington, FL)
# 744    HS                   Waubonsie Valley HS (Aurora, IL)
# 745   4Yr  California Polytechnic State University, San L...
#
# [746 rows x 25 columns]

# %%
pitchers = all_players.loc[(all_players['Pos'] == 'LHP') | (all_players['Pos'] == 'RHP')]
pitchers
# Out:
#                         Name  Year  OvPck  RdPck Rnd            Tm  Pos  DT  \
# 0        Gerrit Cole(minors)  2011      1      1   1       Pirates  RHP NaN
# 1      Danny Hultzen(minors)  2011      2      2   1      Mariners  LHP NaN
# 2       Trevor Bauer(minors)  2011      3      3   1  Diamondbacks  RHP NaN
# 3        Dylan Bundy(minors)  2011      4      4   1       Orioles  RHP NaN
# 6    *Archie Bradley(minors)  2011      7      7  1s  Diamondbacks  RHP NaN
# ..                       ...   ...    ...    ...  ..           ...  ...  ..
# 740  *Mark McCormick(minors)  2005     43     43  1s     Cardinals  RHP NaN
# 741       *Sean West(minors)  2005     44     44  1s       Marlins  LHP NaN
# 743    *Tyler Herron(minors)  2005     46     46  1s     Cardinals  RHP NaN
# 744  *Michael Bowden(minors)  2005     47     47  1s       Red Sox  RHP NaN
# 745   *Garrett Olson(minors)  2005     48     48  1s       Orioles  LHP NaN
#
#      FrRnd Signed  ...     BA    OPS    G.1      W     L   ERA  WHIP    SV  \
# 0    FrRnd      Y  ...  0.163  0.393  250.0  124.0  65.0  3.19  1.11   0.0
# 1    FrRnd      Y  ...    NaN    NaN    6.0    0.0   0.0  0.00  1.80   0.0
# 2    FrRnd      Y  ...  0.069  0.185  222.0   83.0  69.0  3.79  1.24   1.0
# 3    FrRnd      Y  ...  0.143  0.286  175.0   50.0  61.0  4.70  1.30   0.0
# 6    FrRnd      Y  ...  0.095  0.189  329.0   30.0  29.0  3.92  1.36  32.0
# ..     ...    ...  ...    ...    ...    ...    ...   ...   ...   ...   ...
# 740  FrRnd      Y  ...    NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 741  FrRnd      Y  ...  0.059  0.147   22.0    8.0   8.0  5.03  1.58   0.0
# 743  FrRnd      Y  ...    NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 744  FrRnd      Y  ...  0.000  0.000  103.0    3.0   5.0  4.51  1.40   0.0
# 745  FrRnd      Y  ...  0.167  0.310  104.0   14.0  22.0  6.26  1.67   1.0
#
#      Type                                     Drafted Out of
# 0     4Yr  University of California, Los Angeles (Los Ang...
# 1     4Yr       University of Virginia (Charlottesville, VA)
# 2     4Yr  University of California, Los Angeles (Los Ang...
# 3      HS                             Owasso HS (Owasso, OK)
# 6      HS                 Broken Arrow HS (Broken Arrow, OK)
# ..    ...                                                ...
# 740   4Yr                       Baylor University (Waco, TX)
# 741    HS                 Captain Shreve HS (Shreveport, LA)
# 743    HS           Wellington Community HS (Wellington, FL)
# 744    HS                   Waubonsie Valley HS (Aurora, IL)
# 745   4Yr  California Polytechnic State University, San L...
#
# [384 rows x 25 columns]

# %%
batters = all_players.loc[(all_players['Pos'] != 'LHP') & (all_players['Pos'] != 'RHP')]
batters
# Out:
#                           Name  Year  OvPck  RdPck Rnd         Tm Pos  DT  \
# 4       Bubba Starling(minors)  2011      5      5   1     Royals  OF NaN
# 5       Anthony Rendon(minors)  2011      6      6   1  Nationals  3B NaN
# 7     Francisco Lindor(minors)  2011      8      8   1    Indians  SS NaN
# 8          Javier Baez(minors)  2011      9      9   1       Cubs  SS NaN
# 9    *Cory Spangenberg(minors)  2011     10     10  1s     Padres  2B NaN
# ..                         ...   ...    ...    ...  ..        ...  ..  ..
# 730    *Johnny Drennen(minors)  2005     33     33  1s    Indians  OF NaN
# 733       *Travis Buck(minors)  2005     36     36  1s  Athletics  OF NaN
# 735          *Eli Iorg(minors)  2005     38     38  1s     Astros  OF NaN
# 736      *Hank Sanchez(minors)  2005     39     39  1s      Twins  1B NaN
# 742        *Jed Lowrie(minors)  2005     45     45  1s    Red Sox  2B NaN
#
#      FrRnd Signed  ...     BA    OPS  G.1    W    L   ERA  WHIP   SV  Type  \
# 4    FrRnd      Y  ...  0.204  0.544  NaN  NaN  NaN   NaN   NaN  NaN    HS
# 5    FrRnd      Y  ...  0.285  0.848  NaN  NaN  NaN   NaN   NaN  NaN   4Yr
# 7    FrRnd      Y  ...  0.275  0.814  NaN  NaN  NaN   NaN   NaN  NaN    HS
# 8    FrRnd      Y  ...  0.260  0.769  NaN  NaN  NaN   NaN   NaN  NaN    HS
# 9    FrRnd      Y  ...  0.256  0.704  2.0  0.0  0.0  13.5   3.5  0.0    JC
# ..     ...    ...  ...    ...    ...  ...  ...  ...   ...   ...  ...   ...
# 730  FrRnd      Y  ...    NaN    NaN  NaN  NaN  NaN   NaN   NaN  NaN    HS
# 733  FrRnd      Y  ...  0.243  0.715  NaN  NaN  NaN   NaN   NaN  NaN   4Yr
# 735  FrRnd      Y  ...    NaN    NaN  NaN  NaN  NaN   NaN   NaN  NaN   4Yr
# 736  FrRnd      Y  ...    NaN    NaN  NaN  NaN  NaN   NaN   NaN  NaN    HS
# 742  FrRnd      Y  ...  0.257  0.737  NaN  NaN  NaN   NaN   NaN  NaN   4Yr
#
#                                       Drafted Out of
# 4                  Gardner-Edgerton HS (Gardner, KS)
# 5                      Rice University (Houston, TX)
# 7                  Montverde Academy (Montverde, FL)
# 8    Arlington Country Day School (Jacksonville, FL)
# 9       Indian River State College (Fort Pierce, FL)
# ..                                               ...
# 730               Rancho Bernardo HS (San Diego, CA)
# 733             Arizona State University (Tempe, AZ)
# 735          University of Tennessee (Knoxville, TN)
# 736                   Mission Bay HS (San Diego, CA)
# 742              Stanford University (Palo Alto, CA)
#
# [362 rows x 25 columns]

# %%
batters.to_csv('Resources/first_round_csvs/FirstRoundBatters.csv', index=False)

# %%
pitchers.to_csv('Resources/first_round_csvs/FirstRoundPitchers.csv', index=False)
